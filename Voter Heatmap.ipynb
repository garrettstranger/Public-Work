# %%
import pandas as pd
import numpy as np
import gmplot
from IPython.display import display

# %%
geographies = pd.read_csv("geography_5737.csv")

# %%
geographies.head()
# Out:
#                 HHName  LastName FirstName PrimaryAddress1 PrimaryCity  \
# 0  MARIA & ERICK AKERS     AKERS     MARIA             NaN         NaN
# 1          JOHN ALDINE    ALDINE      JOHN             NaN         NaN
# 2     GREGORY ANDERSON  ANDERSON   GREGORY             NaN         NaN
# 3      JENNIFER BEAZER    BEAZER  JENNIFER             NaN         NaN
# 4        LAMONT BERECZ    BERECZ    LAMONT             NaN         NaN
#
#   PrimaryState  PrimaryZip  PrimaryZip4  TelephoneReliabilityCode   Age  \
# 0          NaN         NaN          NaN                       NaN  50.0
# 1          NaN         NaN          NaN                       NaN  49.0
# 2          NaN         NaN          NaN                       NaN  73.0
# 3          NaN         NaN          NaN                       NaN  44.0
# 4          NaN         NaN          NaN                       NaN  44.0
#
#      ...     OfficialParty PrimaryFrequency  CountyName PrecinctNumber  \
# ...

# %%
geographies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131460 entries, 0 to 131459
# Data columns (total 21 columns):
# HHName                      131460 non-null object
# LastName                    131459 non-null object
# FirstName                   131454 non-null object
# PrimaryAddress1             131434 non-null object
# PrimaryCity                 131434 non-null object
# PrimaryState                131434 non-null object
# PrimaryZip                  131433 non-null float64
# PrimaryZip4                 122597 non-null float64
# TelephoneReliabilityCode    100499 non-null float64
# Age                         131437 non-null float64
# Gender                      131460 non-null object
# OfficialParty               131460 non-null object
# PrimaryFrequency            131460 non-null int64
# CountyName                  131460 non-null object
# PrecinctNumber              131460 non-null object
# PrecinctName                131460 non-null object
# ...

# %%
latitudes = geographies["Latitude"]
longitudes = geographies["Longitude"]
gmap = gmplot.GoogleMapPlotter(43.6150186, -116.20231369999999, 10)

# %%
gmap.heatmap(latitudes, longitudes)

# %%
gmap.draw("idaho_distribution.html")
